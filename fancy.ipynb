# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
default_dive_cards = pd.read_csv("data/Fancy - default_dive_cards.csv")
dive_cards = pd.read_csv("data/Fancy - dive_cards.csv")

default_dive_cards["sub_group"].fillna("", inplace=True)
dive_cards["sub_group"].fillna("", inplace=True)
# Out:
# /var/folders/2b/kq41hmfd4mvg6y0yqy9b158h0000gn/T/ipykernel_33973/3004063861.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   default_dive_cards["sub_group"].fillna("", inplace=True)
# /var/folders/2b/kq41hmfd4mvg6y0yqy9b158h0000gn/T/ipykernel_33973/3004063861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import fancy_cards.dive_cards as dc

# %%
base_dir = "/Users/jamessofra/Workspaces/fancy/fancy-cards/fancy_cards/images/"
dive_cards_output_dir = "/Users/jamessofra/Workspaces/fancy/fancy-cards/images/dive_cards/"

default_dive_card_imgs = dc.generate_dive_cards(base_dir, default_dive_cards, "yellow")
dive_card_imgs = dc.generate_dive_cards(base_dir, dive_cards, "blue")

dive_card_imgs["PIL"][42]
# Out:
# <PIL.Image.Image image mode=RGB size=515x800>

# %%
base_url = "https://jsofra.github.io/fancy/images/dive_cards/"

final_dive_cards = dc.write_images(dive_cards_output_dir, dive_card_imgs, "dive", base_url)
final_default_dive_cards = dc.write_images(dive_cards_output_dir, default_dive_card_imgs, "default_dive", base_url)

final_dive_cards.pop("PIL")
final_default_dive_cards.pop("PIL")

final_dive_cards.to_csv("data/Fancy - dive_cards.csv", index=False)
final_default_dive_cards.to_csv("data/Fancy - default_dive_cards.csv", index=False)
